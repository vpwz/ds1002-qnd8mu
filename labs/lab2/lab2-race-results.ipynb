# %% [markdown]
# <a href="https://colab.research.google.com/github/vpwz/ds1002-qnd8mu/blob/main/labs/lab2/lab2-race-results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DS1002 Lab 2: Determine Race Results with R
#
# In this lab you will work with a dataset, writing R to generate the deliverables specified in the cells below.
#
# The dataset for this lab is made up of fictitious results from a road race. Runner information and results is provided in the data.
#
# Answer the questions below with the appropriate R code. Point assignments are indicated for each section. There are 10 total points possible for this lab.
#
# Useful reference material (check all R modules within the Canvas site for more help)
# - [R Reference Material](https://canvas.its.virginia.edu/courses/78571/modules#module_219810).
# - [Plots Samples](https://colab.research.google.com/github/nmagee/ds1002/blob/main/notebooks/25-plots-in-r.ipynb)

# %% [markdown]
# ## Group Submissions
#
# If you are working in a group to complete this lab, you may have no more than 3 members to a group. Group members should be indicated in the cell below -- list both names and UVA computing IDs.
#
# Each student should then submit **the same URL** for the lab in Canvas. (If a group has Member1, Member2, and Member3, only one member needs to save the completed work back to GitHub and all members should submit that URL for grading.)

# %%
NA
# Out:
# [1] NA

# %% [markdown]
# ## 1. Load Libraries & Data (1 pt)
#
# https://raw.githubusercontent.com/nmagee/ds1002/main/data/road-race.csv
#
# Import any necessary libraries and load the remote CSV file below into a data frame.

# %%
library(readr)
library(tidyverse)
library(ggplot2)

install.packages("gridExtra")
library(gridExtra)

url <- "https://raw.githubusercontent.com/nmagee/ds1002/main/data/road-race.csv"

df <- read_csv(url)

df
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ purrr     1.0.2
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
#
# Attaching package: ‘gridExtra’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
#
# Rows: 764 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (2): runner_name, runner_gender
# dbl  (2): runner_bib, runner_age
# time (1): finish_time
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     runner_bib runner_name            runner_age runner_gender finish_time
# 1    1         Loydie Lopes           17         Male          16:01:00
# 2    2         Lorens Crispe          33         Male          15:40:00
# 3    3         Shirline Hasser        22         Female        14:20:00
# 4    4         Alleyn Hartshorn       39         Male          17:06:00
# 5    5         Wang MacColl           50         Male          16:49:00
# 6    6         Tonnie Tidder          44         Male          15:43:00
# 7    7         Hermy Everal           51         Male                NA
# 8    8         Basil Moxsom           44         Male          15:16:00
# 9    9         Lark Bragge            30         Female        15:59:00
# 10  10         Kent Wakely            60         Male          14:29:00
# 11  11         Judye Hattrick         17         Female        15:27:00
# 12  12         Amalea Laurand         17         Agender       16:46:00
# 13  13         Christiana Winspeare   52         Female        16:18:00
# 14  14         Trevar Pegrum          31         Male          16:05:00
# 15  15         Kearney Doumerc        48         Male          15:11:00
# 16  16         Casey Arthur           54         Female        16:41:00
# 17  17         Antony Burnes          19         Male          15:58:00
# 18  18         Ike Ranson             20         Agender       16:45:00
# 19  19         Niels Lynagh           25         Male          17:08:00
# 20  20         Stormy Gideon          43         Female        16:51:00
# 21  21         Carmencita Petrishchev 20         Female        14:15:00
# 22  22         Cristina Brabbs        60         Female        14:20:00
# 23  23         Cordy Jeannaud         27         Female        14:45:00
# 24  24         Rubi Greeson           39         Female        14:46:00
# 25  25         Mickie Drohun          28         Female        16:20:00
# 26  26         Levon Cayette          14         Male          17:07:00
# 27  27         Georges Capoun         38         Male          14:47:00
# 28  28         Yance Ingreda          39         Male          15:40:00
# 29  29         Elfreda Dunmuir        44         Female        15:04:00
# 30  30         Ivar Nutting           33         Male          15:00:00
# ⋮   ⋮          ⋮                      ⋮          ⋮             ⋮
# 735  7         Hermy Everal           51         Male                NA
# 736  8         Basil Moxsom           44         Male          15:16:00
# 737  9         Lark Bragge            30         Female        15:59:00
# 738 10         Kent Wakely            60         Male          14:29:00
# 739 11         Judye Hattrick         17         Female        15:27:00
# 740 12         Amalea Laurand         17         Agender       16:46:00
# 741 13         Christiana Winspeare   52         Female        16:18:00
# 742 14         Trevar Pegrum          31         Male          16:05:00
# 743 15         Kearney Doumerc        48         Male          15:11:00
# 744 16         Casey Arthur           54         Female        16:41:00
# 745 17         Antony Burnes          19         Male          15:58:00
# 746 18         Ike Ranson             20         Agender       16:45:00
# 747 19         Niels Lynagh           25         Male          17:08:00
# 748 20         Stormy Gideon          43         Female        16:51:00
# 749 21         Carmencita Petrishchev 20         Female        14:15:00
# 750 22         Cristina Brabbs        60         Female        14:20:00
# 751 23         Cordy Jeannaud         27         Female        14:45:00
# 752 24         Rubi Greeson           39         Female        14:46:00
# 753 25         Mickie Drohun          28         Female        16:20:00
# 754 26         Levon Cayette          14         Male          17:07:00
# 755 27         Georges Capoun         38         Male          14:47:00
# 756 28         Yance Ingreda          39         Male          15:40:00
# 757 29         Elfreda Dunmuir        44         Female        15:04:00
# 758 30         Ivar Nutting           33         Male          15:00:00
# 759 31         Sibley Golton          42         Female        14:54:00
# 760 32         Winn Froome            48         Male          14:25:00
# 761 33         Gabbie Woollhead       35         Male          14:39:00
# 762 34         Essy Icke              48         Female        14:53:00
# 763 35         Rodd Pessler           53         Male          16:08:00
# 764 36         Gertrude Sinclaire     21         Female        15:15:00

# %% [markdown]
# ## 2. Get Summary Data (1 pt)

# %% [markdown]
# In code, display how many rows and columns are in the raw dataset.

# %%
#
nrow(df)
ncol(df)
# Out:
# [1] 764
# [1] 5

# %% [markdown]
# ## 3. Clean and Organize the Data (2 pts)
#
# Check for data quality.
#
# - Resolve any duplicate rows.
# - If a runner does not have a finish time, they are DNF and should not be counted in the dataset.

# %%
df <- unique(df)
df <- df[!is.na(df$finish_time), ]
df
# Out:
#     runner_bib runner_name            runner_age runner_gender finish_time
# 1    1         Loydie Lopes           17         Male          16:01:00
# 2    2         Lorens Crispe          33         Male          15:40:00
# 3    3         Shirline Hasser        22         Female        14:20:00
# 4    4         Alleyn Hartshorn       39         Male          17:06:00
# 5    5         Wang MacColl           50         Male          16:49:00
# 6    6         Tonnie Tidder          44         Male          15:43:00
# 7    8         Basil Moxsom           44         Male          15:16:00
# 8    9         Lark Bragge            30         Female        15:59:00
# 9   10         Kent Wakely            60         Male          14:29:00
# 10  11         Judye Hattrick         17         Female        15:27:00
# 11  12         Amalea Laurand         17         Agender       16:46:00
# 12  13         Christiana Winspeare   52         Female        16:18:00
# 13  14         Trevar Pegrum          31         Male          16:05:00
# 14  15         Kearney Doumerc        48         Male          15:11:00
# 15  16         Casey Arthur           54         Female        16:41:00
# 16  17         Antony Burnes          19         Male          15:58:00
# 17  18         Ike Ranson             20         Agender       16:45:00
# 18  19         Niels Lynagh           25         Male          17:08:00
# 19  20         Stormy Gideon          43         Female        16:51:00
# 589 303 mins
# 590 222 mins
# 591 173 mins
# 592 188 mins
# 593 307 mins
# 594 262 mins

# %% [markdown]
# Now display the first 10 rows of the cleaned dataset.

# %%
#
head(df, 10)
# Out:
#    runner_bib runner_name      runner_age runner_gender finish_time
# 1   1         Loydie Lopes     17         Male          16:01:00
# 2   2         Lorens Crispe    33         Male          15:40:00
# 3   3         Shirline Hasser  22         Female        14:20:00
# 4   4         Alleyn Hartshorn 39         Male          17:06:00
# 5   5         Wang MacColl     50         Male          16:49:00
# 6   6         Tonnie Tidder    44         Male          15:43:00
# 7   8         Basil Moxsom     44         Male          15:16:00
# 8   9         Lark Bragge      30         Female        15:59:00
# 9  10         Kent Wakely      60         Male          14:29:00
# 10 11         Judye Hattrick   17         Female        15:27:00

# %% [markdown]
# ## 4. Calculate Elapsed Time (3 pts)

# %% [markdown]
# Using R, add a new column named `["finish_minutes"]` to the dataframe that calculates the number of minutes it took for the runner to complete the race. Ideally this is a column consisting of plain integers.
#
# The starting gun was fired at precisely 12:00pm that day.
#
# Note: This is calculated using a built-in function of R, `difftime()` which takes 3 parameters:
#
# - End time
# - Start time
# - Units
#
# The result is an output that figures the difference between the two: `3 days`, `14 years`, `112 mins`, etc.
#
# The syntax for that function is below. Take care to use the proper order of parameters. The `as.POSIXct` casting makes it possible to read a long datetime in the `YYYY-MM-DDTHH:MM` format, a common `datetime` value. The `format` parameter specifies the pattern you are trying to read.
#
# ```
# df$new-column <- (difftime( as.POSIXct(df$end-column, format="%Y-%m-%dT%H:%M"),
#                             as.POSIXct(df$start-column, format="%Y-%m-%dT%H:%M"),
#                             units="min"))
# ```

# %%
twelve <- as.POSIXct("1970-01-1 12:00", format="%Y-%m-%d %H:%M")
df$finish_minutes <- (difftime( as.POSIXct(df$finish_time, format="%Y-%m-%dT%H:%M"),
                            as.POSIXct(twelve, format="%Y-%m-%dT%H:%M"),
                            units="min"))

df
# Out:
#     runner_bib runner_name            runner_age runner_gender finish_time
# 1    1         Loydie Lopes           17         Male          16:01:00
# 2    2         Lorens Crispe          33         Male          15:40:00
# 3    3         Shirline Hasser        22         Female        14:20:00
# 4    4         Alleyn Hartshorn       39         Male          17:06:00
# 5    5         Wang MacColl           50         Male          16:49:00
# 6    6         Tonnie Tidder          44         Male          15:43:00
# 7    8         Basil Moxsom           44         Male          15:16:00
# 8    9         Lark Bragge            30         Female        15:59:00
# 9   10         Kent Wakely            60         Male          14:29:00
# 10  11         Judye Hattrick         17         Female        15:27:00
# 11  12         Amalea Laurand         17         Agender       16:46:00
# 12  13         Christiana Winspeare   52         Female        16:18:00
# 13  14         Trevar Pegrum          31         Male          16:05:00
# 14  15         Kearney Doumerc        48         Male          15:11:00
# 15  16         Casey Arthur           54         Female        16:41:00
# 16  17         Antony Burnes          19         Male          15:58:00
# 17  18         Ike Ranson             20         Agender       16:45:00
# 18  19         Niels Lynagh           25         Male          17:08:00
# 19  20         Stormy Gideon          43         Female        16:51:00
# 20  21         Carmencita Petrishchev 20         Female        14:15:00
# 21  22         Cristina Brabbs        60         Female        14:20:00
# 22  23         Cordy Jeannaud         27         Female        14:45:00
# 23  24         Rubi Greeson           39         Female        14:46:00
# Based on the minutes it took each runner to complete the race, identify the top three places for each gender.
#
# There are several ways to do this, some of which require less code than others. You will only be graded for producing the correct output, not on how elegant/advanced your programming is.

# %%
df$runner_gender <- factor(df$runner_gender)

topThree <- df %>%
arrange(runner_gender, finish_minutes )%>%
group_by(runner_gender) %>%
mutate(Rank = row_number()) %>%
filter(Rank <=3)

topThree
# Out:
#    runner_bib runner_name            runner_age runner_gender finish_time
# 1  321        Jacobo Telling         33         Agender       14:47:00
# 2  480        Tomasina Greensall     22         Agender       15:12:00
# 3  332        Ina Bonifant           30         Agender       15:17:00
# 4  249        Sephira Kirgan         33         Bigender      14:24:00
# 5  546        Chauncey Langthorne    16         Bigender      14:29:00
# 6  263        Ernestus Draper        45         Bigender      14:58:00
# 7   21        Carmencita Petrishchev 20         Female        14:15:00
# 8  134        Marylin Standering     18         Female        14:15:00
# 9  238        Melloney Fonteyne      20         Female        14:15:00
# 10 152        Patrice Draye          18         Genderfluid   14:15:00
# 11 606        Nonna Restill          57         Genderfluid   14:24:00
# 12 421        Neysa Willatt          60         Genderfluid   14:33:00
# 13 547        Patin Dawidowitsch     17         Genderqueer   15:27:00
# 14 527        Bobby Sykes            52         Genderqueer   15:28:00
# 15 590        Abigale Beedle         41         Genderqueer   15:34:00
# 16 393        Ker Dearden            62         Male          14:15:00
# 17 114        Arin Maffezzoli        52         Male          14:18:00
# 18 325        Holt Teissier          36         Male          14:18:00
# 19 341        Gaylor Buckett         17         Non-binary    14:29:00
# 20  38        Mellie Merryfield      54         Non-binary    15:03:00
# 21 426        Base Dukes             62         Non-binary    15:19:00
# 22 283        Karyl Pyne             38         Polygender    14:21:00
# 23 356        Alair Blyde            42         Polygender    14:27:00
# 24 578        Dagmar Bedburrow       47         Polygender    14:49:00
#    finish_minutes Rank
# 1  167 mins       1
# 2  192 mins       2
# 3  197 mins       3
# 4  144 mins       1
# 5  149 mins       2
# 6  178 mins       3
# 7  135 mins       1
# 8  135 mins       2
# 9  135 mins       3
# 10 135 mins       1
# 11 144 mins       2
# 12 153 mins       3
# 13 207 mins       1
# 14 208 mins       2
# 15 214 mins       3
# 16 135 mins       1
# 17 138 mins       2
# 18 138 mins       3
# 19 149 mins       1
# 20 183 mins       2
# 21 199 mins       3
# 22 141 mins       1
# 23 147 mins       2
# 24 169 mins       3

# %% [markdown]
# ## 6. Plot the Data (3 pts)

# %% [markdown]
# Finally, using `ggplot2` create two plots of the data -- density plots of race finishers.
#
# - In the first plot use `finish_minutes` as the x axis.
# - In the second plot use `runner_age` as the x axis.
# - Use `runner_gender` as the fill.
# - We suggest using a `geom_density(alpha=0.2)` or therabouts to see layers through one another.
# - Use the `gridExtra` library's `grid.arrange()` method to plot them both.
#
# You will note that since this is artificial data you will be able to see the gender layers clearly enough but they will not be statistically meaningful.

# %%
#
p1 <- ggplot(df, aes(x = finish_minutes, fill = runner_gender)) +
      geom_density(alpha = 0.2)
      p1
# Out:
# Don't know how to automatically pick scale for object of type <difftime>.
# Defaulting to continuous.
# plot without title

# %%
 p2 <- ggplot(df, aes(x = runner_age, fill = runner_gender)) +
      geom_density(alpha = 0.2)
      p2
# Out:
# plot without title
